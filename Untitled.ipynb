# %%
lalalallalal

# %%
une_var = 32

# %% [markdown]
# que j'aime à faire apprendre un nombre utile aux sages

# %%
Si tu fais push mais qu eje suis entrain d'écrire que se passe t'il ?
# Out:
#   Cell In[1], line 1
#     Si tu fais push mais qu eje suis entrain d'écrire que se passe t'il ?
#        ^
# SyntaxError: invalid syntax

# %%
print("oustiti")
# Out:
# oustiti
